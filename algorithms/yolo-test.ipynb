# %%
import torch 
import utils
display = utils.notebook_init()
import cv2
import numpy as np
# Out:
# YOLOv5  2022-10-22 Python-3.10.8 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
# Setup complete  (16 CPUs, 15.4 GB RAM, 397.0/936.2 GB disk)

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
vs = cv2.VideoCapture(0)
_ , imgs = vs.read()

results = model(imgs, size=640)  # includes NMS
cv2.imshow('frame', imgs)
results.show()
    # results.print()  # print results to screen
    # print(results)  # print results to screen

    # results.xyxy[0]  # img1 predictions (tensor)
    # results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Using cache found in C:\Users\Tanay Garg/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-10-22 Python-3.10.8 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
#
# Fusing layers...
# requirements: C:\coding_projects\yolo_project\yolo\Lib\site-packages\requirements.txt not found, check failed.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=640x480>
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
